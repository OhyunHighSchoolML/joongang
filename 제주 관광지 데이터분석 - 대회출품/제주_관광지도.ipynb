# %%
import numpy as np
import pandas as pd

# %%
visit14=pd.read_excel('/content/내국인_제주여행_방문지_2014.xlsx')
visit15=pd.read_excel('/content/내국인_제주여행_방문지_2015.xlsx')
visit16=pd.read_excel('/content/내국인_제주여행_방문지_2016.xlsx')

# %%
visit14
# Out:
#    응답자수 (명)  한라산 (%)  오름(좌표는 거문오름) (%)  ...  골프장(좌표는 세인트포) (%)  카지노 (%)  기타 (%)
# 0     13469      6.9               6.1  ...                3.6      0.3      26
#
# [1 rows x 61 columns]

# %%
visit15
# Out:
#    응답자수 (명)  한라산 (%)  오름(좌표는 거문오름) (%)  ...  골프장(좌표는 세인트포) (%)  카지노 (%)  기타 (%)
# 0      9540      6.3               6.8  ...                3.3      0.3    28.4
#
# [1 rows x 61 columns]

# %%
visit16
# Out:
#    응답자수 (명)  한라산 (%)  오름(좌표는 거문오름) (%)  ...  골프장(좌표는 세인트포) (%)  카지노 (%)  기타 (%)
# 0      5558     16.5              21.4  ...                  6      0.6    76.9
#
# [1 rows x 61 columns]

# %%
col14=[]
col15=[]
col16=[]
for i in visit14.columns:
  col14.append(i[:i.find(' (')])
for i in visit15.columns:
  col15.append(i[:i.find(' (')])
for i in visit16.columns:
  col16.append(i[:i.find(' (')])
col14
# Out:
# ['응답자수',
#  '한라산',
#  '오름(좌표는 거문오름)',
#  '성산일출봉',
#  '섬(좌표는 우도)',
#  '올레길(1코스)',
#  '폭포(좌표는 정방폭포)',
#  '동굴(좌표는 만장굴)',
#  '해수욕장(좌표는 삼양검은모래해변)',
#  '비자림',
#  '한라수목원',
#  '서귀포자연휴양림',
#  '절물자연휴양림',
#  '용두암',
#  '주상절리대',
#  '한림공원',
#  '응답자수',
#  '국립제주박물관',
#  '도립미술관',
#  '민속자연사박물관',
#  '제주돌문화공원',
#  '제주세계자연유산센터',
#  '이중섭미술관',
#  '서복전시관',
#  '제주4.3평화공원',
#  '응답자수',
#  '동문시장',
#  '중앙로지하상가',
#  '바오젠거리',
#  '제주5일장(제주/서귀포)',
#  '신라면세점',
#  '롯데면세점',
#  '제주관광공사면세점',
#  '공항면세점(JDC면세점)',
#  '응답자수',
#  '제주목관아',
#  '항몽유적지',
#  '성읍민속마을',
#  '삼양동선사유적',
#  '제주추사관',
#  '관덕정',
#  '이중섭거주지',
#  '하멜기념비',
#  '응답자수',
#  '미로공원(좌표는 김녕)',
#  '에코랜드',
#  '제주경마공원',
#  '불교사찰(좌표는 관음사)',
#  '아쿠아플라넷',
#  '테디베어박물관',
#  '소인국테마파크',
#  '잠수함관광(좌표는 서귀포잠수함)',
#  '신비의도로',
#  '생각하는정원',
#  '드라마촬영지(좌표는 건축학개론)',
#  '제주별빛누리공원',
#  '유람선(요트투어포함, 좌표는 서귀포유람선)',
#  '제주바다체험장',
#  '골프장(좌표는 세인트포)',
#  '카지노',
#  '기타']

# %%
visit14.columns=col14
visit15.columns=col15
visit16.columns=col16
visit14
# Out:
#     응답자수  한라산  오름(좌표는 거문오름)  성산일출봉  ...  제주바다체험장  골프장(좌표는 세인트포)  카지노  기타
# 0  13469  6.9           6.1   13.1  ...      1.4            3.6  0.3  26
#
# [1 rows x 61 columns]

# %%
visitlist=[visit14, visit15, visit16]
visitname=['visit14', 'visit15', 'visit16']
for i, name in zip(visitlist, visitname):
  globals()['{}_1'.format(name)]=pd.DataFrame(i.iloc[0, 0:16])
  globals()['{}_2'.format(name)]=pd.DataFrame(i.iloc[0, 16:25])
  globals()['{}_3'.format(name)]=pd.DataFrame(i.iloc[0, 25:34])
  globals()['{}_4'.format(name)]=pd.DataFrame(i.iloc[0, 34:43])
  globals()['{}_5'.format(name)]=pd.DataFrame(i.iloc[0, 43:])

# %%
visit15_1
# Out:
#                          0
# 응답자수                9540.0
# 한라산                    6.3
# 오름(좌표는 거문오름)           6.8
# 성산일출봉                 12.9
# 섬(좌표는 우도)              9.5
# 올레길(1코스)               8.6
# 폭포(좌표는 정방폭포)           8.0
# 동굴(좌표는 만장굴)            3.8
# 해수욕장(좌표는 삼양검은모래해변)    16.2
# 비자림                    3.8
# 한라수목원                  2.8
# 서귀포자연휴양림               1.9
# 절물자연휴양림                2.2
# 용두암                    8.3
# 주상절리대                  5.7
# 한림공원                   3.7

# %%
visit14_1=visit14_1.transpose()
visit14_2=visit14_2.transpose()
visit14_3=visit14_3.transpose()
visit14_4=visit14_4.transpose()
visit14_5=visit14_5.transpose()
visit15_1=visit15_1.transpose()
visit15_2=visit15_2.transpose()
visit15_3=visit15_3.transpose()
visit15_4=visit15_4.transpose()
visit15_5=visit15_5.transpose()
visit16_1=visit16_1.transpose()
visit16_2=visit16_2.transpose()
visit16_3=visit16_3.transpose()
visit16_4=visit16_4.transpose()
visit16_5=visit16_5.transpose()

# %%
visit14.loc[0]
# Out:
# 응답자수                       13469.0
# 한라산                            6.9
# 오름(좌표는 거문오름)                   6.1
# 성산일출봉                         13.1
# 섬(좌표는 우도)                      8.6
#                             ...
# 유람선(요트투어포함, 좌표는 서귀포유람선)        4.0
# 제주바다체험장                        1.4
# 골프장(좌표는 세인트포)                  3.6
# 카지노                            0.3
# 기타                            26.0
# Name: 0, Length: 61, dtype: float64

# %%
dflist=[visit14_1, visit14_2, visit14_3, visit14_4, visit14_5, visit15_1, visit15_2, visit15_3, visit15_4, visit15_5, visit16_1, visit16_2, visit16_3, visit16_4, visit16_5]

# %%
list14=[]
for i in range(0, 5):
  list14.append(int(dflist[i].iloc[0,0]))
  for j in list(dflist[i].iloc[0,1:]):
    list14.append(int(int(dflist[i].iloc[0,0])*(j/100)))
visit14.loc[0]=list14

# %%
visit14
# Out:
#     응답자수    한라산  오름(좌표는 거문오름)   성산일출봉  ...  제주바다체험장  골프장(좌표는 세인트포)   카지노    기타
# 0  13469  929.0         821.0  1764.0  ...     88.0          226.0  18.0  1636
#
# [1 rows x 61 columns]

# %%
list15=[]
for i in range(5, 10):
  list15.append(int(dflist[i].iloc[0,0]))
  for j in list(dflist[i].iloc[0,1:]):
    list15.append(int(int(dflist[i].iloc[0,0])*(j/100)))
visit15.loc[0]=list15

# %%
list16=[]
for i in range(10, 15):
  list16.append(int(dflist[i].iloc[0,0]))
  for j in list(dflist[i].iloc[0,1:]):
    list16.append(int(int(dflist[i].iloc[0,0])*(j/100)))
visit16.loc[0]=list16

# %%
visit15
# Out:
#    응답자수    한라산  오름(좌표는 거문오름)   성산일출봉  ...  제주바다체험장  골프장(좌표는 세인트포)   카지노      기타
# 0  9540  601.0         648.0  1230.0  ...     55.0          153.0  13.0  1318.0
#
# [1 rows x 61 columns]

# %%
visit16
# Out:
#    응답자수    한라산  오름(좌표는 거문오름)   성산일출봉  ...  제주바다체험장  골프장(좌표는 세인트포)   카지노      기타
# 0  5558  917.0        1189.0  2184.0  ...    107.0            229  22.0  2942.0
#
# [1 rows x 61 columns]

# %%
for i in visitlist:
  i.drop(['응답자수', '카지노', '기타'], axis=1, inplace=True)

# %%
visit14
# Out:
#      한라산  오름(좌표는 거문오름)   성산일출봉  ...  유람선(요트투어포함, 좌표는 서귀포유람선)  제주바다체험장  골프장(좌표는 세인트포)
# 0  929.0         821.0  1764.0  ...                      251     88.0          226.0
#
# [1 rows x 54 columns]

# %%
visit14=visit14.transpose()
visit15=visit15.transpose()
visit16=visit16.transpose()

# %%
visit14
# Out:
#                               0
# 한라산                       929.0
# 오름(좌표는 거문오름)              821.0
# 성산일출봉                    1764.0
# 섬(좌표는 우도)                1158.0
# 올레길(1코스)                 1252.0
# 폭포(좌표는 정방폭포)             1077.0
# 동굴(좌표는 만장굴)               538.0
# 해수욕장(좌표는 삼양검은모래해변)       1750.0
# 비자림                       498.0
# 한라수목원                     377.0
# 서귀포자연휴양림                  336.0
# 절물자연휴양림                   350.0
# 용두암                      1225.0
# 주상절리대                     835.0
# 한림공원                      565.0
# 국립제주박물관                   228.0
# 도립미술관                      66.0
# 민속자연사박물관                  282.0
# 제주돌문화공원                   151.0
# 제주세계자연유산센터                 91.0
# 이중섭미술관                    390.0
# 서복전시관                      30.0
# 제주4.3평화공원                  79.0
# 동문시장                     1361.0
# 중앙로지하상가                   193.0
# 바오젠거리                      77.0
# 제주5일장(제주/서귀포)             562.0
# 신라면세점                      73.0
# ...

# %%
visiterdata=[]
for i in range(len(visit14)):
  visiterdata.append(int(visit14.iloc[i,0])+int(visit15.iloc[i,0])+int(visit16.iloc[i,0]))

# %%
visiterdata
# Out:
# [2447,
#  2658,
#  5178,
#  3681,
#  3511,
#  3335,
#  1583,
#  6329,
#  1682,
#  1049,
#  867,
#  981,
#  3438,
#  2439,
#  1545,
#  540,
#  268,
#  740,
#  480,
#  268,
#  1186,
#  89,
#  310,
#  4576,
#  625,
#  539,
#  1473,
#  260,
#  504,
#  1647,
#  4250,
#  237,
#  183,
#  1196,
#  86,
#  149,
#  406,
#  1355,
#  533,
#  1269,
#  2416,
#  515,
#  449,
#  1712,
#  812,
#  886,
#  550,
#  1446,
#  476,
#  1232,
#  248,
#  628,
#  250,
#  608]

# %%
visit14.index
# Out:
# Index(['한라산', '오름(좌표는 거문오름)', '성산일출봉', '섬(좌표는 우도)', '올레길(1코스)', '폭포(좌표는 정방폭포)',
#        '동굴(좌표는 만장굴)', '해수욕장(좌표는 삼양검은모래해변)', '비자림', '한라수목원', '서귀포자연휴양림',
#        '절물자연휴양림', '용두암', '주상절리대', '한림공원', '국립제주박물관', '도립미술관', '민속자연사박물관',
#        '제주돌문화공원', '제주세계자연유산센터', '이중섭미술관', '서복전시관', '제주4.3평화공원', '동문시장',
#        '중앙로지하상가', '바오젠거리', '제주5일장(제주/서귀포)', '신라면세점', '롯데면세점', '제주관광공사면세점',
#        '공항면세점(JDC면세점)', '제주목관아', '항몽유적지', '성읍민속마을', '삼양동선사유적', '제주추사관', '관덕정',
#        '이중섭거주지', '하멜기념비', '미로공원(좌표는 김녕)', '에코랜드', '제주경마공원', '불교사찰(좌표는 관음사)',
#        '아쿠아플라넷', '테디베어박물관', '소인국테마파크', '잠수함관광(좌표는 서귀포잠수함)', '신비의도로', '생각하는정원',
#        '드라마촬영지(좌표는 건축학개론)', '제주별빛누리공원', '유람선(요트투어포함, 좌표는 서귀포유람선)', '제주바다체험장',
#        '골프장(좌표는 세인트포)'],
#       dtype='object')

# %%
visit=pd.DataFrame({'방문객' : visiterdata}, index=visit14.index)

# %%
visit
# Out:
#                           방문객
# 한라산                      2447
# 오름(좌표는 거문오름)             2658
# 성산일출봉                    5178
# 섬(좌표는 우도)                3681
# 올레길(1코스)                 3511
# 폭포(좌표는 정방폭포)             3335
# 동굴(좌표는 만장굴)              1583
# 해수욕장(좌표는 삼양검은모래해변)       6329
# 비자림                      1682
# 한라수목원                    1049
# 서귀포자연휴양림                  867
# 절물자연휴양림                   981
# 용두암                      3438
# 주상절리대                    2439
# 한림공원                     1545
# 국립제주박물관                   540
# 도립미술관                     268
# 민속자연사박물관                  740
# 제주돌문화공원                   480
# 제주세계자연유산센터                268
# 이중섭미술관                   1186
# 서복전시관                      89
# 제주4.3평화공원                 310
# 동문시장                     4576
# 중앙로지하상가                   625
# 바오젠거리                     539
# 제주5일장(제주/서귀포)            1473
# 신라면세점                     260
# 롯데면세점                     504
# 제주관광공사면세점                1647
# ...

# %%
revisit14=pd.read_excel('/content/내국인_제주여행_재방문지_2014.xlsx')
revisit15=pd.read_excel('/content/내국인_제주여행_재방문지_2015.xlsx')
revisit16=pd.read_excel('/content/내국인_제주여행_재방문지_2016.xlsx')

# %%
revisit14
# Out:
#                     재방문지별(1)      2014   2014.1  ...   2014.3    2014.4   2014.5
# 0                   재방문지별(1)       1순위      1순위  ...      2순위       3순위      3순위
# 1                   재방문지별(1)  응답자수 (명)  구성비 (%)  ...  구성비 (%)  응답자수 (명)  구성비 (%)
# 2                         전체      3719      100  ...      100      2650      100
# 3                        한라산       537     14.4  ...      4.7        65      2.5
# 4               오름(좌표는 거문오름)       220      5.9  ...      6.2        79        3
# 5                      성산일출봉       391     10.5  ...      8.9       207      7.8
# 6                  섬(좌표는 우도)       425     11.4  ...      6.9       173      6.5
# 7                   올레길(1코스)       327      8.8  ...      8.1       151      5.7
# 8               폭포(좌표는 정방폭포)        83      2.2  ...      3.5       124      4.7
# 9                동굴(좌표는 만장굴)        18      0.5  ...      1.4        39      1.5
# 10        해수욕장(좌표는 삼양검은모래해변)       330      8.9  ...      9.7       200      7.6
# ...

# %%
revisitlist=[revisit14,revisit15,revisit16]
for i in revisitlist:
  i.drop(i.columns[2:7], axis=1, inplace=True)
  i.drop(i.index[0:3], inplace=True)
  i.drop(i.index[54:], inplace=True)

# %%
revisit15
# Out:
#                     재방문지별(1) 2015
# 3                        한라산  268
# 4               오름(좌표는 거문오름)  123
# 5                      성산일출봉  271
# 6                  섬(좌표는 우도)  362
# 7                   올레길(1코스)  204
# 8               폭포(좌표는 정방폭포)   85
# 9                동굴(좌표는 만장굴)   17
# 10        해수욕장(좌표는 삼양검은모래해변)  338
# 11                       비자림   79
# 12                     한라수목원   16
# 13                  서귀포자연휴양림   11
# 14                   절물자연휴양림   50
# 15                       용두암   38
# 16                     주상절리대   56
# 17                      한림공원   33
# 18                   국립제주박물관    7
# 19                     도립미술관    9
# 20                  민속자연사박물관    6
# 21                   제주돌문화공원   10
# 22                제주세계자연유산센터    3
# 23                    이중섭미술관   15
# 24                     서복전시관    0
# 25                 제주4.3평화공원    2
# 26                      동문시장   86
# 27                   중앙로지하상가    7
# 28                     바오젠거리   13
# ...

# %%
revisiterdata=[]
for i in range(len(revisit14)):
  revisiterdata.append(revisit14.iloc[i,1]+revisit15.iloc[i,1]+revisit16.iloc[i,1])

# %%
revisiterdata
# Out:
# [1246,
#  608,
#  1103,
#  1294,
#  847,
#  299,
#  55,
#  1360,
#  357,
#  68,
#  71,
#  185,
#  124,
#  231,
#  134,
#  20,
#  21,
#  22,
#  36,
#  6,
#  39,
#  1,
#  13,
#  324,
#  13,
#  26,
#  72,
#  10,
#  14,
#  58,
#  155,
#  3,
#  1,
#  28,
#  0,
#  6,
#  4,
#  22,
#  5,
#  75,
#  460,
#  30,
#  18,
#  263,
#  28,
#  18,
#  40,
#  21,
#  27,
#  28,
#  19,
#  66,
#  24,
#  225]

# %%
visit['재방문객']=None
visit['재방문객']=revisiterdata

# %%
visit
# Out:
#                           방문객  재방문객
# 한라산                      2447  1246
# 오름(좌표는 거문오름)             2658   608
# 성산일출봉                    5178  1103
# 섬(좌표는 우도)                3681  1294
# 올레길(1코스)                 3511   847
# 폭포(좌표는 정방폭포)             3335   299
# 동굴(좌표는 만장굴)              1583    55
# 해수욕장(좌표는 삼양검은모래해변)       6329  1360
# 비자림                      1682   357
# 한라수목원                    1049    68
# 서귀포자연휴양림                  867    71
# 절물자연휴양림                   981   185
# 용두암                      3438   124
# 주상절리대                    2439   231
# 한림공원                     1545   134
# 국립제주박물관                   540    20
# 도립미술관                     268    21
# 민속자연사박물관                  740    22
# 제주돌문화공원                   480    36
# 제주세계자연유산센터                268     6
# 이중섭미술관                   1186    39
# 서복전시관                      89     1
# 제주4.3평화공원                 310    13
# 동문시장                     4576   324
# 중앙로지하상가                   625    13
# ...

# %%
visitnumber=list(visit['방문객'])
revisitnumber=list(visit['재방문객'])

# %%
len(visitnumber)
# Out:
# 54

# %%
len(revisitnumber)
# Out:
# 54

# %%
ratio=[]
for i in range(0, 54):
  ratio.append(round(revisitnumber[i]/visitnumber[i], 3))

# %%
ratio
# Out:
# [0.509,
#  0.229,
#  0.213,
#  0.352,
#  0.241,
#  0.09,
#  0.035,
#  0.215,
#  0.212,
#  0.065,
#  0.082,
#  0.189,
#  0.036,
#  0.095,
#  0.087,
#  0.037,
#  0.078,
#  0.03,
#  0.075,
#  0.022,
#  0.033,
#  0.011,
#  0.042,
#  0.071,
#  0.021,
#  0.048,
#  0.049,
#  0.038,
#  0.028,
#  0.035,
#  0.036,
#  0.013,
#  0.005,
#  0.023,
#  0.0,
#  0.04,
#  0.01,
#  0.016,
#  0.009,
#  0.059,
#  0.19,
#  0.058,
#  0.04,
#  0.154,
#  0.034,
#  0.02,
#  0.073,
#  0.015,
#  0.057,
#  0.023,
#  0.077,
#  0.105,
#  0.096,
#  0.37]

# %%
for i in range(0, 54):
  ratio[i]=round(ratio[i]*100, 1)
ratio
# Out:
# [50.9,
#  22.9,
#  21.3,
#  35.2,
#  24.1,
#  9.0,
#  3.5,
#  21.5,
#  21.2,
#  6.5,
#  8.2,
#  18.9,
#  3.6,
#  9.5,
#  8.7,
#  3.7,
#  7.8,
#  3.0,
#  7.5,
#  2.2,
#  3.3,
#  1.1,
#  4.2,
#  7.1,
#  2.1,
#  4.8,
#  4.9,
#  3.8,
#  2.8,
#  3.5,
#  3.6,
#  1.3,
#  0.5,
#  2.3,
#  0.0,
#  4.0,
#  1.0,
#  1.6,
#  0.9,
#  5.9,
#  19.0,
#  5.8,
#  4.0,
#  15.4,
#  3.4,
#  2.0,
#  7.3,
#  1.5,
#  5.7,
#  2.3,
#  7.7,
#  10.5,
#  9.6,
#  37.0]

# %%
visit['재방문비율(%)']=None
visit['재방문비율(%)']=ratio
visit
# Out:
#                           방문객  재방문객  재방문비율(%)
# 한라산                      2447  1246      50.9
# 오름(좌표는 거문오름)             2658   608      22.9
# 성산일출봉                    5178  1103      21.3
# 섬(좌표는 우도)                3681  1294      35.2
# 올레길(1코스)                 3511   847      24.1
# 폭포(좌표는 정방폭포)             3335   299       9.0
# 동굴(좌표는 만장굴)              1583    55       3.5
# 해수욕장(좌표는 삼양검은모래해변)       6329  1360      21.5
# 비자림                      1682   357      21.2
# 한라수목원                    1049    68       6.5
# 서귀포자연휴양림                  867    71       8.2
# 절물자연휴양림                   981   185      18.9
# 용두암                      3438   124       3.6
# 주상절리대                    2439   231       9.5
# 한림공원                     1545   134       8.7
# 국립제주박물관                   540    20       3.7
# 도립미술관                     268    21       7.8
# 민속자연사박물관                  740    22       3.0
# 제주돌문화공원                   480    36       7.5
# ...

# %%
import folium as fol

# %%
print("folium version is", fol.__version__)
# Out:
# folium version is 0.8.3

# %%
pip install git+https://github.com/python-visualization/branca.git@master
# Out:
# ...
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to /tmp/pip-req-build-5goqdmhu
#   Running command git clone -q https://github.com/python-visualization/branca.git /tmp/pip-req-build-5goqdmhu
# ...
#   Created wheel for branca: filename=branca-0.4.1+3.g5887b9b-cp36-none-any.whl size=24523 sha256=ba237be70ea5d31e8a8d34fe5f1333f332750cb08daf153ed94fb7515ff69f1b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lcr0j3xw/wheels/14/bc/41/d6078abe73beea93d98c014bba54c395224cabb54f95b9d248
# Successfully built branca

# %%
location=pd.read_excel('/content/제주관광지좌표.xlsx')
location
# Out:
#                      관광지좌표
# 0                      한라산
# 1    33.362824, 126.529180
# 2                 오름(거문오름)
# 3    33.454830, 126.717914
# 4                    성산일출봉
# ..                     ...
# 103  33.239112, 126.558714
# 104                제주바다체험장
# 105  33.554682, 126.721903
# 106             골프장(세인트포)
# 107  33.520025, 126.741261
#
# [108 rows x 1 columns]

# %%
loca=[]
for i in range(1, 108, 2):
  loca.append(location.iloc[i,0].split(', '))
for i in range(0, 54):
  loca[i][0]=float(loca[i][0])
  loca[i][1]=float(loca[i][1])

# %%
loca
# Out:
# [[33.362824, 126.52918],
#  [33.45483, 126.717914],
#  [33.458664, 126.942328],
#  [33.504207, 126.953877],
#  [33.47914, 126.896251],
#  [33.244825, 126.571784],
#  [33.529109, 126.771241],
#  [33.526092, 126.586379],
#  [33.484455, 126.806506],
#  [33.469929, 126.493246],
#  [33.31134, 126.460222],
#  [33.439516, 126.629434],
#  [33.516237, 126.512063],
#  [33.23773, 126.425056],
#  [33.389631, 126.239304],
#  [33.513439, 126.548976],
#  [33.452512, 126.48984],
#  [33.50653, 126.531618],
#  [33.448596, 126.658639],
#  [33.456957, 126.714388],
#  [33.245843, 126.564937],
#  [33.244847, 126.57091],
#  [33.451149, 126.618934],
#  [33.511603, 126.526087],
#  [33.513121, 126.525183],
#  [33.489673, 126.490357],
#  [33.496898, 126.475409],
#  [33.486059, 126.487724],
#  [33.490669, 126.486436],
#  [33.241287, 126.424483],
#  [33.507189, 126.493032],
#  [33.513592, 126.522005],
#  [33.452093, 126.40774],
#  [33.386349, 126.799698],
#  [33.523088, 126.58781],
#  [33.249934, 126.278326],
# ...

# %%
visit['좌표']=None
visit['좌표']=loca

# %%
visit
# Out:
#                           방문객  재방문객  재방문비율(%)                       좌표
# 한라산                      2447  1246      50.9   [33.362824, 126.52918]
# 오름(좌표는 거문오름)             2658   608      22.9   [33.45483, 126.717914]
# 성산일출봉                    5178  1103      21.3  [33.458664, 126.942328]
# 섬(좌표는 우도)                3681  1294      35.2  [33.504207, 126.953877]
# 올레길(1코스)                 3511   847      24.1   [33.47914, 126.896251]
# 폭포(좌표는 정방폭포)             3335   299       9.0  [33.244825, 126.571784]
# 동굴(좌표는 만장굴)              1583    55       3.5  [33.529109, 126.771241]
# 해수욕장(좌표는 삼양검은모래해변)       6329  1360      21.5  [33.526092, 126.586379]
# 비자림                      1682   357      21.2  [33.484455, 126.806506]
# 한라수목원                    1049    68       6.5  [33.469929, 126.493246]
# 서귀포자연휴양림                  867    71       8.2   [33.31134, 126.460222]
# 절물자연휴양림                   981   185      18.9  [33.439516, 126.629434]
# ...

# %%
visit.describe()
# Out:
#                방문객         재방문객   재방문비율(%)
# count    54.000000    54.000000  54.000000
# mean   1409.629630   189.314815   8.872222
# std    1418.776437   344.441513  10.244307
# min      86.000000     0.000000   0.000000
# 25%     477.000000    18.250000   2.850000
# 50%     876.500000    33.000000   4.850000
# 75%    1673.250000   177.500000   9.375000
# max    6329.000000  1360.000000  50.900000

# %%
visit['상태']=None
visit.loc[(visit['방문객'] > 1409.6)&(visit['재방문비율(%)'] > 4.8), '상태']='A'
visit.loc[(visit['방문객'] <= 1409.6)&(visit['재방문비율(%)'] > 4.8), '상태']='B'
visit.loc[(visit['방문객'] > 1409.6)&(visit['재방문비율(%)'] <= 4.8), '상태']='C'
visit.loc[(visit['방문객'] <= 1409.6)&(visit['재방문비율(%)'] <= 4.8), '상태']='D'
visit
# Out:
#                           방문객  재방문객  재방문비율(%)                       좌표 상태
# 한라산                      2447  1246      50.9   [33.362824, 126.52918]  A
# 오름(좌표는 거문오름)             2658   608      22.9   [33.45483, 126.717914]  A
# 성산일출봉                    5178  1103      21.3  [33.458664, 126.942328]  A
# 섬(좌표는 우도)                3681  1294      35.2  [33.504207, 126.953877]  A
# 올레길(1코스)                 3511   847      24.1   [33.47914, 126.896251]  A
# 폭포(좌표는 정방폭포)             3335   299       9.0  [33.244825, 126.571784]  A
# 동굴(좌표는 만장굴)              1583    55       3.5  [33.529109, 126.771241]  C
# 해수욕장(좌표는 삼양검은모래해변)       6329  1360      21.5  [33.526092, 126.586379]  A
# 비자림                      1682   357      21.2  [33.484455, 126.806506]  A
# 한라수목원                    1049    68       6.5  [33.469929, 126.493246]  B
# 서귀포자연휴양림                  867    71       8.2   [33.31134, 126.460222]  B
# 절물자연휴양림                   981   185      18.9  [33.439516, 126.629434]  B
# ...

# %%
visit.groupby('상태').count()
# Out:
#     방문객  재방문객  재방문비율(%)  좌표
# 상태
# A    14    14        14  14
# B    13    13        13  13
# C     5     5         5   5
# D    22    22        22  22

# %%
m = fol.Map(location=[33.3666, 126.5333], zoom_start=11)
for i in range(0, 54):
  if visit['상태'].iloc[i]=='A':
     fol.Marker(location=visit['좌표'].iloc[i], 
               tooltip=(visit.index[i]+'\n방문객 수: '+str(visit['방문객'].iloc[i])+'명\n재방문율: '+str(visit['재방문비율(%)'].iloc[i])+'%'),
               icon=fol.Icon(color='blue')).add_to(m)
  elif visit['상태'].iloc[i]=='B':
     fol.Marker(location=visit['좌표'].iloc[i], 
               tooltip=(visit.index[i]+'\n방문객 수: '+str(visit['방문객'].iloc[i])+'명\n재방문율: '+str(visit['재방문비율(%)'].iloc[i])+'%'),
               icon=fol.Icon(color='green')).add_to(m)
  elif visit['상태'].iloc[i]=='C':
     fol.Marker(location=visit['좌표'].iloc[i], 
               tooltip=(visit.index[i]+'\n방문객 수: '+str(visit['방문객'].iloc[i])+'명\n재방문율: '+str(visit['재방문비율(%)'].iloc[i])+'%'),
               icon=fol.Icon(color='red')).add_to(m)
  else:
     fol.Marker(location=visit['좌표'].iloc[i], 
               tooltip=(visit.index[i]+'\n방문객 수: '+str(visit['방문객'].iloc[i])+'명\n재방문율: '+str(visit['재방문비율(%)'].iloc[i])+'%'),
               icon=fol.Icon(color='gray')).add_to(m)
m.save('map.html')
